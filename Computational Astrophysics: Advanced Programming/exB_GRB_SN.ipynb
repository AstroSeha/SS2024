# %% [markdown]
# ### An exercise about observational astrnomy: a gamma-ray burst with an associated supernova

# %%
from astropy.io import fits
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from astropy import units as u

# %%
file = '/Users/sehalee/Documents/1-Universität Potsdam/24SS/CompAstro_Advanced/101219Bdata/MS_UVB_1D.fits'

# %%
fits.getheader(file)
# Out:
# SIMPLE  =                    T / conforms to FITS standard
# BITPIX  =                  -64 / array data type
# NAXIS   =                    1 / number of array dimensions
# NAXIS1  =                 7278
# EXTEND  =                    T
# CRPIX1  =                  1.0
# CDELT1  =                 0.04
# CRVAL1  =               298.92
# CRPIX2  =                  1.0
# CDELT2  =                 0.16
# CRVAL2  =    -10.1800003051758
# DATE    = '2011-03-13T13:03:18'
# CTYPE1  = 'LINEAR  '
# ORIGIN  = 'ESO     '
# TELESCOP= 'ESO-VLT-U2'
# INSTRUME= 'XSHOOTER'
# OBJECT  = 'GRB     '
# RA      =             12.23146
# DEC     =            -34.56632
# HIERARCH ESO SEQ ARM = 'UVB     '
# HIERARCH ESO TEL AIRM END = 1.716
# HIERARCH ESO TEL AIRM START = 1.559
# HIERARCH ESO DET OUT1 GAIN = 1.61
# HIERARCH ESO DET OUT1 CONAD = 0.62
# EXPTIME =               1200.0
# HIERARCH ESO TEL AMBI FWHM END = 1.75
# HIERARCH ESO TEL AMBI FWHM START = 1.63
# HIERARCH ESO TEL IA FWHM = 1.0
# ...

# %%
# List of FITS file paths

files = [
    '/Users/sehalee/Documents/1-Universität Potsdam/24SS/CompAstro_Advanced/101219Bdata/MS_UVB_1D.fits',
    '/Users/sehalee/Documents/1-Universität Potsdam/24SS/CompAstro_Advanced/101219Bdata/MS_VIS_1D.fits',
    '/Users/sehalee/Documents/1-Universität Potsdam/24SS/CompAstro_Advanced/101219Bdata/NIR_phys_stare_rec_1.fits',
    '/Users/sehalee/Documents/1-Universität Potsdam/24SS/CompAstro_Advanced/101219Bdata/UVB_phys_stare_rec_2.fits',
    '/Users/sehalee/Documents/1-Universität Potsdam/24SS/CompAstro_Advanced/101219Bdata/VIS_phys_stare_rec_2.fits',
    '/Users/sehalee/Documents/1-Universität Potsdam/24SS/CompAstro_Advanced/101219Bdata/NIR_phys_stare_rec_2.fits',
    '/Users/sehalee/Documents/1-Universität Potsdam/24SS/CompAstro_Advanced/101219Bdata/UVB_phys_stare_rec_3.fits',
    '/Users/sehalee/Documents/1-Universität Potsdam/24SS/CompAstro_Advanced/101219Bdata/VIS_phys_stare_rec_3.fits',
    '/Users/sehalee/Documents/1-Universität Potsdam/24SS/CompAstro_Advanced/101219Bdata/MS_UVB_1D.fits' #just to fill the empty slot
]

# Read the FITS files and store the data in a 3x3 array
data_array = np.empty((3, 3), dtype=object)
for i in range(3):
    for j in range(3):
        with fits.open(files[i*3 + j]) as hdul:
            data_array[i, j] = hdul[0].data

# %%
print(data_array.shape)
print(data_array[0, 0].shape)
# Out:
# (3, 3)
# (7278,)

# %%
print(data_array[0][0] == fits.getdata(files[0]))
print(data_array[0][1] == fits.getdata(files[1]))
print(data_array[2][1] == fits.getdata(files[7]))
# Out:
# [ True  True  True ...  True  True  True]
# [ True  True  True ...  True  True  True]
# [ True  True  True ...  True  True  True]

# %%
print(data_array[0][0].shape)
# Out:
# (7278,)

# %%
fits.getheader(files[0])
# Out:
# SIMPLE  =                    T / conforms to FITS standard
# BITPIX  =                  -64 / array data type
# NAXIS   =                    1 / number of array dimensions
# NAXIS1  =                 7278
# EXTEND  =                    T
# CRPIX1  =                  1.0
# CDELT1  =                 0.04
# CRVAL1  =               298.92
# CRPIX2  =                  1.0
# CDELT2  =                 0.16
# CRVAL2  =    -10.1800003051758
# DATE    = '2011-03-13T13:03:18'
# CTYPE1  = 'LINEAR  '
# ORIGIN  = 'ESO     '
# TELESCOP= 'ESO-VLT-U2'
# INSTRUME= 'XSHOOTER'
# OBJECT  = 'GRB     '
# RA      =             12.23146
# DEC     =            -34.56632
# HIERARCH ESO SEQ ARM = 'UVB     '
# HIERARCH ESO TEL AIRM END = 1.716
# HIERARCH ESO TEL AIRM START = 1.559
# HIERARCH ESO DET OUT1 GAIN = 1.61
# HIERARCH ESO DET OUT1 CONAD = 0.62
# EXPTIME =               1200.0
# HIERARCH ESO TEL AMBI FWHM END = 1.75
# HIERARCH ESO TEL AMBI FWHM START = 1.63
# HIERARCH ESO TEL IA FWHM = 1.0
# ...

# %%
# Convert the array to a pandas DataFrame
df = pd.DataFrame(data_array)

# %%
# Define column and row names
column_names = ['UVB', 'VIS', 'NIR']
row_names = ['epoch1', 'epoch2', 'epoch3']

# Assign names to columns and rows
df.columns = column_names
df.index = row_names

# %%
df
# Out:
#                                                       UVB  \
# epoch1  [3.740918301043186e-14, -1.8777759905265652e-1...
# epoch2  [4.6382482e-15, -1.566297e-15, -2.9859798e-15,...
# epoch3  [1.4686584e-14, -9.65493e-15, -2.5524403e-14, ...
#
#                                                       VIS  \
# epoch1  [-1.7289476599534337e-13, 1.586385475836182e-1...
# epoch2  [2.8467656e-17, 4.7119993e-17, 5.5481174e-17, ...
# epoch3  [-3.8304908e-17, -3.408053e-17, 3.1483662e-17,...
#
#                                                       NIR
# epoch1  [1.9790901e-16, 4.4328916e-16, 7.897391e-16, 9...
# epoch2  [1.14786e-16, 2.3273435e-16, 3.8656506e-16, 5....
# epoch3  [3.740918301043186e-14, -1.8777759905265652e-1...

# %%
# check the data length

for i in range(3):
    for j in range(3):
        print(data_array[i][j].shape)
# Out:
# (7278,)
# (12159,)
# (29701,)
# (14845,)
# (24457,)
# (29701,)
# (14845,)
# (24457,)
# (7278,)

# %%
# array of wavelengths: lambda = CRVAL1 + i * CDELT1
# for the first file
CDELT1  =                 0.04                                                  
CRVAL1  =               298.92

wavelength = CRVAL1 + np.arange(data_array[0][0].shape[0]) * CDELT1
print(wavelength[:4])
# Out:
# [298.92 298.96 299.   299.04]

# %%
# plot

plt.plot(wavelength, data_array[0][0])
plt.ylim((-0.5e-17,5e-17))
# Out:
# (-5e-18, 5e-17)

# %%
wavelengths = np.zeros((3, 3), dtype=object)

# read CRVAL1 and CDELT1 from the headers
for i in range(3): 
    for j in range(3):
        with fits.open(files[i*3 + j]) as hdul:
            CRVAL1 = hdul[0].header['CRVAL1']
            CDELT1 = hdul[0].header['CDELT1']
            wavelengths[i, j] = CRVAL1 + np.arange(data_array[i][j].shape[0]) * CDELT1
            # convert from nm to angstroms
            wavelengths[i, j] *= 10
            # units of angstroms
            wavelengths[i, j] = wavelengths[i, j] * u.AA
            

print(wavelengths[0, 0][:4])
print(wavelengths[0, 1][:4])
print(wavelengths[0, 2][:4])
print(wavelengths[0, 0].shape) #uvb
print(wavelengths[0, 1].shape) #vis
print(wavelengths[0, 2].shape) #nir
# Out:
# [2989.2 2989.6 2990.  2990.4] Angstrom
# [5336.8 5337.2 5337.6 5338. ] Angstrom
# [9940.  9940.5 9941.  9941.5] Angstrom
# (7278,)
# (12159,)
# (29701,)

# %% [markdown]
# #### Plot the observed flux (in units of erg s-1 cm-2 Å-1) as a function of wavelength (in Å) for epoch 1,2 and 3. Make one matplotlib panel for each epoch.

# %%
fig, ax = plt.subplots(3, 1, figsize=(10, 8))

ax[0].plot(wavelengths[0, 0], data_array[0, 0],color='blue')
ax[1].plot(wavelengths[0, 1], data_array[0, 1],color='green')
ax[2].plot(wavelengths[0, 2], data_array[0, 2],color='darkorange')
for i in range(3):
    ax[i].set_title(column_names[i])
    ax[i].set_ylim((-0.5e-17, 5e-17))
    ax[i].set_ylabel('Flux [erg/s/cm^2/Å]')
ax[2].set_xlabel('Wavelength [Å]')
plt.suptitle('Epoch 1', fontsize="xx-large")
plt.tight_layout()

# %%
fig, ax = plt.subplots(3, 1, figsize=(10, 8))

ax[0].plot(wavelengths[1, 0], data_array[1, 0],color='blue')
ax[1].plot(wavelengths[1, 1], data_array[1, 1],color='green')
ax[2].plot(wavelengths[1, 2], data_array[1, 2],color='darkorange')
for i in range(3):
    ax[i].set_title(column_names[i])
    ax[i].set_ylim((-0.5e-17, 5e-17))
    ax[i].set_ylabel('Flux [erg/s/cm^2/Å]')
ax[2].set_xlabel('Wavelength [Å]')
plt.suptitle('Epoch 2', fontsize="xx-large")
plt.tight_layout()

# %%
fig, ax = plt.subplots(2, 1, figsize=(10, 8))

ax[0].plot(wavelengths[2, 0], data_array[2, 0],color='blue')
ax[1].plot(wavelengths[2, 1], data_array[2, 1],color='green')
for i in range(2):
    ax[i].set_title(column_names[i])
    ax[i].set_ylim((-0.5e-17, 5e-17))
    ax[i].set_ylabel('Flux [erg/s/cm^2/Å]')
ax[1].set_xlabel('Wavelength [Å]')
plt.suptitle('Epoch 3', fontsize="xx-large")
plt.tight_layout()

# %% [markdown]
# #### The data is relatively noisy. Rebin the data by a factor of 5, by calculating the median wavelength and flux, for each set of 5 pixels. Replot the data. The following commands can be used to rebin the data

# %%
# rebinning
rebinned_data_array = np.empty_like(data_array)
rebinned_wavelengths = np.empty_like(wavelengths)

for i in range(3):
    for j in range(3):
        K = data_array[i, j].shape[0] // 5
        flux = np.zeros(K)
        wavelength = np.zeros(K)
        for k in range(K):
            flux[k] = np.median(data_array[i, j][k*5:(k+1)*5])
            wavelength[k] = np.median(wavelengths[i, j][k*5:(k+1)*5].value)
        rebinned_data_array[i, j] = flux
        rebinned_wavelengths[i, j] = wavelength * u.AA

print(rebinned_data_array[0, 0].shape)
print(rebinned_data_array[0, 0][:4])
print(rebinned_wavelengths[0, 0].shape)
print(rebinned_wavelengths[0, 0][:4])
# Out:
# (1455,)
# [ 1.91304644e-14  1.16971709e-14  5.76349678e-15 -3.18220893e-14]
# (1455,)
# [2990. 2992. 2994. 2996.] Angstrom

# %%
# replotting
# epoch 1

fig, ax = plt.subplots(3, 1, figsize=(10, 8))

i = 0
#set colors
C = ['darkblue', 'darkgreen', 'darkred']
for j in range(3):
    ax[j].plot(rebinned_wavelengths[i, j], rebinned_data_array[i, j], color=C[j])
    ax[j].set_title(column_names[j])
    ax[j].set_ylim((-0.5e-17, 5e-17))
    ax[j].set_ylabel('Flux [erg/s/cm^2/Å]')

ax[2].set_xlabel('Wavelength [Å]')
plt.suptitle('Epoch 1, Rebinned', fontsize="xx-large")
plt.tight_layout()

# %%
# replotting
# epoch 2

fig, ax = plt.subplots(3, 1, figsize=(10, 8))

i = 1
for j in range(3):
    ax[j].plot(rebinned_wavelengths[i, j], rebinned_data_array[i, j], color=C[j])
    ax[j].set_title(column_names[j])
    ax[j].set_ylim((-0.5e-17, 5e-17))
    ax[j].set_ylabel('Flux [erg/s/cm^2/Å]')

ax[2].set_xlabel('Wavelength [Å]')
plt.suptitle('Epoch 2, Rebinned', fontsize="xx-large")
plt.tight_layout()

# %%
# replotting
# epoch 3

fig, ax = plt.subplots(2, 1, figsize=(10, 8))

i = 2

for j in range(2):
    ax[j].plot(rebinned_wavelengths[i, j], rebinned_data_array[i, j], color=C[j])
    ax[j].set_title(column_names[j])
    ax[j].set_ylim((-0.5e-17, 5e-17))
    ax[j].set_ylabel('Flux [erg/s/cm^2/Å]')

ax[1].set_xlabel('Wavelength [Å]')
plt.suptitle('Epoch 3, Rebinned', fontsize="xx-large")
plt.tight_layout()

# %% [markdown]
# #### GRB afterglows usually follow a power law spectrum of the form, Flux = b λ-a, where the normalisation is fading in time. Perform a power law fit for the spectrums of each epoch. For what epochs do a power law give a good description of the spectrum? You only need to perform a fit for UVB and VIS (NIR is too noisy).
#
# #### Hint: Each spectrum is very noise at the lowest and highest wavelengths. This is because of noise in the detector. To obtain a good fit, I suggest that you trim the data before doing the fit.

# %% [markdown]
# For UVB for example do:
#
# - SelectedWavelength = numpy.where((Wavelength>3500)*(Wavelength<5500))
# - Wavelength = Wavelength[SelectedWavelength]
# - Flux = Flux[SelectedWavelength]
#
# And for VIS
#
# - SelectedWavelength = numpy.where((Wavelength>5600)*(Wavelength<9000))
# - Wavelength = Wavelength[SelectedWavelength]
# - Flux = Flux[SelectedWavelength]
